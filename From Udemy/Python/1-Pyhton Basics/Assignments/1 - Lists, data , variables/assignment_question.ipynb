# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print("Hello, World!")
# Out:
# Running cells with 'venv (Python 3.12.0)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n venv ipykernel --update-deps --force-reinstall'

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here
userInput  = input("Write you wanna print:")
print(userInput)

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here
num = int(input("Enter the Number:"))
if (num < 0 ):
    print("The entered number is negative.")
elif(num > 0):
    print("The entered number is positive.")
else:
    print("The number is zero.")

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here
num1 = int(input("Enter the first number:"))
num2 = int(input("Enter the Second number:"))
num3 = int(input("Enter the third number:"))
if (num1 > (num2 and num3)):
    largest = num1
elif(num2 > (num1 and num3)):
    largest = num2
elif(num3 > (num1 and num2)):
    largest = num3
print(f"The largest number is :{largest}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Your code here
# ----> 2 num1 = int(input("Enter the first number:"))
#       3 num2 = int(input("Enter the Second number:"))
#       4 num3 = int(input("Enter the third number:"))
#
# TypeError: 'str' object is not callable

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# # Your code here
# num = int(input("Enter the number:"))
# print(num)

# i = 0

# while(i == 5 ):
#     print(num)
#     num2 = num-i
#     num1 = num2 * (num - 1)
#     # num = num * (num - i)
#     i += 1

# print(num1)
def factorial(n):
    if (n==0):
        return 1
    else:
        return n * factorial(n-1)
    
num = int(input("Enter the number"))
print(f"The factorial of {num} is {factorial(num)}.")

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here
int = 23
flot = 2.0
str = "Bikash"
bool = bool
print(int)
print(flot)
print(str)
print(bool)

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# Your code here
num1 = 12 
num2 = 34.98
print(f"Before swapping the variable value:{num1}",type(num1))
print(f"Before swapping the variable value:{num2}",type(num2))

num1 = float(num1)
num2 = int(num2)

print(f"Before swapping the variable value:{num1}",type(num1))
print(f"Before swapping the variable value:{num2}",type(num2))
# Out:
# Before swapping the variable value:12 <class 'int'>
# Before swapping the variable value:34.98 <class 'float'>
# Before swapping the variable value:12.0 <class 'float'>
# Before swapping the variable value:34 <class 'int'>

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here
cal = input("Enter the value:")
F = (cal * (9/5)) + 32 

print(f"The corrosponding Faranheit is {F} F")
# Out:
# The corrosponding Faranheit is 98.60000000000001 F

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here
str1 = "Bikash"
str2 = "Akash"

str3 = str1 +" "+ str2
print(str3)
# Out:
# Bikash Akash

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here
input = input("Enter the any value:")
print(type(input))
# Out:
# <class 'str'>

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here
a = int(input("Enter the first value:"))
b = int(input("Enter the second value:"))
sum = a + b
dif = a - b
mult = a * b
div = a / b 
print(f"The sum of the these two value is {sum}")
print(f"The difference of the these two value is {dif}")
print(f"The multiplication of the these two value is {mult}")
print(f"The division of the these two value is {div}")
# Out:
# The sum of the these two value is 75
# The difference of the these two value is 5
# The multiplication of the these two value is 1400
# The division of the these two value is 1.1428571428571428

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here
x = int(input("Enter the first value:"))
y = int(input("Enter the second value:"))

if (x > y):
    print("The first value is the greater.")
elif(x<y):
    print("The second value is greater.")
else:
    print("The both values are equal.")
# Out:
# The first value is the greater.

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here
a = "hari"
b = "hari"
x = 3
y = 6
if (a== b and x ==y ):
    print("All the values are same.")
elif(a == b or x != y):
    print("Strings are same but numbers are different.")
else:
    print("All the values are not same.")
# Out:
# Strings are same but numbers are different.

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here
inp = int(input("Entere the number :"))
sqr = inp * inp
print(f"The square of the given number is: {sqr}")
# Out:
# The square of the given number is: 16

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here
# int = int(input("Enter the number:"))
int = -2
if (int >= 0):
    if ((int % 2) == 0):
        print(f"The entered {int} value is even")
    elif ((int%2) != 2):
        print(f"The entered {int} value is odd.")
else:
    print(f"The entered value {int} is negative value.")
# Out:
# The entered value -2 is negative value.

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here
def sum_of_natural (x):
    if (x == 0):
        return 0
    else:
        return x + sum_of_natural(x-1)

# int = int(input("Enter the any natural number:"))
int = 9
print(f"The sum of natural number of {int} is {sum_of_natural(int)}")
# Out:
# The sum of natural number of 9 is 45

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here
# year = int(input("Enter a year: "))
year = 2025
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(f"{year} is a leap year.")
else:
    print(f"{year} is not a leap year.")
# Out:
# 2025 is not a leap year.

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here
# str = str(input("Enter the any strings:"))
str = "Bikash"
str = str[::-1]
print(str)
# Out:
# hsakiB

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here
# str = str(input("Enter the string to check is it palidrome or not:"))
str = "eve"
str_rev = str[::-1]
if (str == str_rev):
    print(f"The word {str} is palidrome {str_rev}")
else:
    print(f"The entered world {str} is not palidrome.")
# Out:
# The entered world eve1 is not palidrome.

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code here
list = [5,4,5,2,8,6,7]
print(f"Before sorting the list is {list}")
list_sort = sorted(list)
print(f"After sorting the list is {list_sort}")
# Out:
# Before sorting the list is [5, 4, 5, 2, 8, 6, 7]
# After sorting the list is [2, 4, 5, 5, 6, 7, 8]
