# %%
tpl = ()
print(tpl)
print(type(tpl))
# Out:
# ()
# <class 'tuple'>

# %%
tuple([3, 4, 2, 5])
# Out:
# (3, 4, 2, 5)

# %%
list((3, 2, 6, 5))
# Out:
# [3, 2, 6, 5]

# %%
mixed_tpl = (2, 5, "Bikash", True)

# %%
print(mixed_tpl)
# Out:
# (2, 5, 'Bikash', True)
